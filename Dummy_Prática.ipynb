# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf

# %%
df = pd.read_excel('limite_crédito_escolaridade.xlsx')
df.head()
# Out:
#    Idade  RendimentoTotal  Salario  LimitedeCreditoImediato  \
# 0     70            10736     5214                      400
# 1     68             5000     5000                      380
# 2     44             5800     5800                      500
# 3     72             4300     4300                     2000
# 4     75             4400     4400                     3000
#
#    LimitedoChequeEspecial       Escolaridade
# 0                     500  Fundamental_Medio
# 1                     600  Fundamental_Medio
# 2                     800  Fundamental_Medio
# 3                    1000  Fundamental_Medio
# 4                    1000  Fundamental_Medio

# %%
df = pd.get_dummies(df, prefix=['Escolaridade'])
df.head()
# Out:
#    Idade  RendimentoTotal  Salario  LimitedeCreditoImediato  \
# 0     70            10736     5214                      400
# 1     68             5000     5000                      380
# 2     44             5800     5800                      500
# 3     72             4300     4300                     2000
# 4     75             4400     4400                     3000
#
#    LimitedoChequeEspecial  Escolaridade_Fundamental_Medio  \
# 0                     500                            True
# 1                     600                            True
# 2                     800                            True
# 3                    1000                            True
# 4                    1000                            True
#
#    Escolaridade_Superior_Pos
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False

# %%
df.corr()
# Out:
#                                    Idade  RendimentoTotal   Salario  \
# Idade                           1.000000         0.066396  0.063227
# RendimentoTotal                 0.066396         1.000000  0.960551
# Salario                         0.063227         0.960551  1.000000
# LimitedeCreditoImediato         0.064149         0.031041  0.081792
# LimitedoChequeEspecial          0.075883         0.858120  0.888839
# Escolaridade_Fundamental_Medio -0.110892        -0.396191 -0.475479
# Escolaridade_Superior_Pos       0.110892         0.396191  0.475479
#
#                                 LimitedeCreditoImediato  \
# Idade                                          0.064149
# RendimentoTotal                                0.031041
# Salario                                        0.081792
# LimitedeCreditoImediato                        1.000000
# LimitedoChequeEspecial                         0.226990
# Escolaridade_Fundamental_Medio                -0.259433
# ...

# %%
df.columns
# Out:
# Index(['Idade', 'RendimentoTotal', 'Salario', 'LimitedeCreditoImediato',
#        'LimitedoChequeEspecial', 'Escolaridade_Fundamental_Medio',
#        'Escolaridade_Superior_Pos'],
#       dtype='object')

# %%
function = 'LimitedoChequeEspecial~Idade+RendimentoTotal+Salario+LimitedeCreditoImediato+Escolaridade_Fundamental_Medio+Escolaridade_Superior_Pos'
model = smf.ols(formula=function, data=df).fit()
print(model.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     LimitedoChequeEspecial   R-squared:                       0.848
# Model:                                OLS   Adj. R-squared:                  0.830
# Method:                     Least Squares   F-statistic:                     46.89
# Date:                    Sat, 08 Jun 2024   Prob (F-statistic):           4.07e-16
# Time:                            11:42:24   Log-Likelihood:                -441.00
# No. Observations:                      48   AIC:                             894.0
# Df Residuals:                          42   BIC:                             905.2
# Df Model:                               5
# Covariance Type:                nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
function = 'LimitedoChequeEspecial~RendimentoTotal+Salario+LimitedeCreditoImediato+Escolaridade_Fundamental_Medio+Escolaridade_Superior_Pos'
model = smf.ols(formula=function, data=df).fit()
print(model.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     LimitedoChequeEspecial   R-squared:                       0.848
# Model:                                OLS   Adj. R-squared:                  0.834
# Method:                     Least Squares   F-statistic:                     59.99
# Date:                    Sat, 08 Jun 2024   Prob (F-statistic):           4.92e-17
# Time:                            11:42:33   Log-Likelihood:                -441.01
# No. Observations:                      48   AIC:                             892.0
# Df Residuals:                          43   BIC:                             901.4
# Df Model:                               4
# Covariance Type:                nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
function = 'LimitedoChequeEspecial~Salario+LimitedeCreditoImediato+Escolaridade_Fundamental_Medio+Escolaridade_Superior_Pos'
model = smf.ols(formula=function, data=df).fit()
print(model.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     LimitedoChequeEspecial   R-squared:                       0.842
# Model:                                OLS   Adj. R-squared:                  0.831
# Method:                     Least Squares   F-statistic:                     77.92
# Date:                    Sat, 08 Jun 2024   Prob (F-statistic):           1.23e-17
# Time:                            11:42:40   Log-Likelihood:                -442.00
# No. Observations:                      48   AIC:                             892.0
# Df Residuals:                          44   BIC:                             899.5
# Df Model:                               3
# Covariance Type:                nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
function = 'LimitedoChequeEspecial~Salario+LimitedeCreditoImediato+Escolaridade_Fundamental_Medio'
model = smf.ols(formula=function, data=df).fit()
print(model.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     LimitedoChequeEspecial   R-squared:                       0.842
# Model:                                OLS   Adj. R-squared:                  0.831
# Method:                     Least Squares   F-statistic:                     77.92
# Date:                    Sat, 08 Jun 2024   Prob (F-statistic):           1.23e-17
# Time:                            11:42:53   Log-Likelihood:                -442.00
# No. Observations:                      48   AIC:                             892.0
# Df Residuals:                          44   BIC:                             899.5
# Df Model:                               3
# Covariance Type:                nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# ...

# %%
function = 'LimitedoChequeEspecial~Salario+LimitedeCreditoImediato+Escolaridade_Fundamental_Medio-1'
model = smf.ols(formula=function, data=df).fit()
print(model.summary())
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     LimitedoChequeEspecial   R-squared:                       0.842
# Model:                                OLS   Adj. R-squared:                  0.831
# Method:                     Least Squares   F-statistic:                     77.92
# Date:                    Sat, 08 Jun 2024   Prob (F-statistic):           1.23e-17
# Time:                            11:50:27   Log-Likelihood:                -442.00
# No. Observations:                      48   AIC:                             892.0
# Df Residuals:                          44   BIC:                             899.5
# Df Model:                               3
# Covariance Type:                nonrobust
# ...
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# ...

# %%
df['Previsto'] = model.predict()

# %%
df.head()
# Out:
#    Idade  RendimentoTotal  Salario  LimitedeCreditoImediato  \
# 0     70            10736     5214                      400
# 1     68             5000     5000                      380
# 2     44             5800     5800                      500
# 3     72             4300     4300                     2000
# 4     75             4400     4400                     3000
#
#    LimitedoChequeEspecial  Escolaridade_Fundamental_Medio  \
# 0                     500                            True
# 1                     600                            True
# 2                     800                            True
# 3                    1000                            True
# 4                    1000                            True
#
#    Escolaridade_Superior_Pos     Previsto
# 0                      False   667.168325
# 1                      False   541.873639
# 2                      False  1043.384525
# 3                      False  1366.076106
# ...
